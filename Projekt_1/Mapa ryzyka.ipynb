# %%
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches
import numpy as np

x = np.linspace(1, 5, 500)
y = np.linspace(1, 5, 500)
X, Y = np.meshgrid(x, y)
Z = X * Y

#(istotność, częstotliwość)
ryzyka = {
    "I": ("Wahania cen surowców i dostaw", (4, 3)),
    "II": ("Jakość i bezpieczeństwo żywności", (5, 2)),
    "III": ("Zmieniające się regulacje prawne i podatkowe", (4, 3)),
    "IV": ("Cyberzagrożenia i ochrona danych", (4, 2)),
    "V": ("Katastrofy naturalne", (3, 2)),
    "VI": ("Niewypłacalność franczyzobiorców", (4, 2)),
    "VII": ("Wahania kursów walut", (3, 3)),
    "VIII": ("Wzrost kosztów zatrudnienia pracownika", (2, 4)),
    "IX": ("Nagłe zmiany trendów żywieniowych", (3, 4)),
    "X": ("Awaria systemów IT (kasy, zamówienia online)", (5, 3)),
    "XI": ("Utrata reputacji", (5, 2)),
    "XII": ("Wahania cen energii", (3, 4)),
    "XIII": ("Presja konkurencyjna", (4, 3)),
    "XIV": ("Wybuch epidemii wśród pracowników", (4, 3)),
    "XV": ("Zakażenia pokarmowe", (5, 2)),
}

punkt_labels = {}
for num, (label, coords) in ryzyka.items():
    if coords in punkt_labels:
        punkt_labels[coords].append(num)
    else:
        punkt_labels[coords] = [num]

fig, ax = plt.subplots(figsize=(12, 8), layout='constrained')

cmap = plt.get_cmap("RdYlGn_r")
c = ax.contourf(X, Y, Z, levels=100, cmap=cmap)

for (x, y), nums in punkt_labels.items():
    label_text = ", ".join(nums)
    ax.plot(x, y, 'ko')
    ax.text(x + 0.1, y, label_text, fontsize=10, weight='bold')

ax.set_title("MAPA RYZYKA", fontsize=16)
ax.set_xlabel("Istotność", fontsize=12)
ax.set_ylabel("Częstość", fontsize=12)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels(["b.małe", "małe", "średnie", "duże", "b.duże"], fontsize=10)
ax.set_yticks([1, 2, 3, 4, 5])
ax.set_yticklabels(["b.małe", "małe", "średnie", "duże", "b.duże"], fontsize=10)

cbar = fig.colorbar(c, ax=ax)
cbar.set_label("Poziom ryzyka (I x C)", fontsize=11)

legend_text = (
    "Legenda ryzyk:\n"
    "I – Wahania cen surowców i dostaw\n"
    "II – Jakość i bezpieczeństwo\n"
    "III – Zmieniające się regulacje prawne i podatkowe\n"
    "IV – Cyberzagrożenia i ochrona danych\n"
    "V – Katastrofy naturalne\n"
    "VI - Niewypłacalność franczyzobiorców\n"
    "VII - Wahania kursów walut\n"
    "VIII - Wzrost kosztów zatrudnienia pracownika\n"
    "IX - Nagłe zmiany trendów żywieniowych\n"
    "X - Awaria systemów IT (kasy, zamówienia online)\n"
    "XI - Utrata reputacji\n"
    "XII - Wahania cen energii\n"
    "XIII - Presja konkurencyjna\n"
    "XIV - Wybuch epidemii wśród pracowników\n"
    "XV - Zakażenia pokarmowe\n"
)

fig.text(1.02, 0.5, legend_text, va='center', fontsize=11, family='monospace')

plt.subplots_adjust(right=0.75) 
plt.show()
# Out:
# C:\Users\wpyrt\AppData\Local\Temp\ipykernel_18856\199558405.py:87: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(right=0.75)  # więcej miejsca z prawej strony

# %%
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches
import numpy as np


x = np.linspace(1, 5, 500)
y = np.linspace(1, 5, 500)
X, Y = np.meshgrid(x, y)
Z = X * Y  

# (istotność, częstotliwość)
ryzyka = {
    "I": ("Wahania cen surowców i dostaw", (4, 3)),
    "II": ("Jakość i bezpieczeństwo żywności", (5, 2)),
    "III": ("Zmieniające się regulacje prawne i podatkowe", (4, 3)),
    "IV": ("Cyberzagrożenia i ochrona danych", (4, 2)),
    "V": ("Katastrofy naturalne", (3, 2))
}

punkt_labels = {}
for num, (label, coords) in ryzyka.items():
    if coords in punkt_labels:
        punkt_labels[coords].append(num)
    else:
        punkt_labels[coords] = [num]

fig, ax = plt.subplots(figsize=(12, 8), layout='constrained')

cmap = plt.get_cmap("RdYlGn_r")
c = ax.contourf(X, Y, Z, levels=100, cmap=cmap)

for (x, y), nums in punkt_labels.items():
    label_text = ", ".join(nums)
    ax.plot(x, y, 'ko')
    ax.text(x + 0.1, y, label_text, fontsize=10, weight='bold')

ax.set_title("MAPA RYZYKA", fontsize=16)
ax.set_xlabel("Istotność", fontsize=12)
ax.set_ylabel("Częstość", fontsize=12)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels(["b.małe", "małe", "średnie", "duże", "b.duże"], fontsize=10)
ax.set_yticks([1, 2, 3, 4, 5])
ax.set_yticklabels(["b.małe", "małe", "średnie", "duże", "b.duże"], fontsize=10)

cbar = fig.colorbar(c, ax=ax)
cbar.set_label("Poziom ryzyka (I x C)", fontsize=11)

legend_text = (
    "Legenda ryzyk:\n"
    "I – Wahania cen surowców i dostaw\n"
    "II – Jakość i bezpieczeństwo\n"
    "III – Zmieniające się regulacje prawne i podatkowe\n"
    "IV – Cyberzagrożenia i ochrona danych\n"
    "V – Katastrofy naturalne\n"
)

fig.text(1.02, 0.5, legend_text, va='center', fontsize=11, family='monospace')

plt.subplots_adjust(right=0.75)  
plt.show()
# Out:
# C:\Users\wpyrt\AppData\Local\Temp\ipykernel_18856\2145794501.py:67: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(right=0.75)  # więcej miejsca z prawej strony
